# %% [markdown]
# ## Sigma0 Analysis - PNB

# %% [markdown]
# Pré-processamento: Orbit File -> Calibration -> Speckle Filtering -> Terrain Correction -> Spatial Subset

# %%
# Importações
# Bibliotecas básicas
import rasterio as rst
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
from seaborn import pointplot

# Rasterio
import rasterio as rst
from rasterio.mask import mask
from rasterio.plot import show
# Raster stats
from rasterstats import zonal_stats
from scipy.stats import iqr
# Processamento de dados
import numpy as np
import pandas as pd
import geopandas as gpd

# %%
# Área de estudo no Parque Nacional de Brasília - Formação Florestal
area = gpd.read_file('C:/Users/jales/Desktop/PNB/classes/formacao_florestal_32723.GEOJSON')

# %% [markdown]
# ## Cálculo das estatísticas

# %% [markdown]
# #### 11/09/2019

# %%
# Zonal stats das formações florestais - VH
ff_2019_09_11_VH = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20190911_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
ff_2019_09_11_VH = pd.DataFrame(ff_2019_09_11_VH)
ff_2019_09_11_VH['date'] = '11/09/2019'
ff_2019_09_11_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649      -16.21312     -14.013806  11/09/2019

# %%
# Zonal stats das formações florestais - VV
ff_2019_09_11_VV = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20190911_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
ff_2019_09_11_VV = pd.DataFrame(ff_2019_09_11_VV)
ff_2019_09_11_VV['date'] = '11/09/2019'
ff_2019_09_11_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243       -7.95418  11/09/2019

# %% [markdown]
# #### 23/09/2019

# %%
# Zonal stats das formações florestais - VH
ff_2019_09_23_VH = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20190923_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
ff_2019_09_23_VH = pd.DataFrame(ff_2019_09_23_VH)
ff_2019_09_23_VH['date'] = '23/09/2019'
ff_2019_09_23_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -14.724693     -15.873222     -13.640703  23/09/2019

# %%
df_VH = ff_2019_09_11_VH.append(ff_2019_09_23_VH)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019

# %%
# Zonal stats das formações florestais - VV
ff_2019_09_23_VV = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20190923_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
ff_2019_09_23_VV = pd.DataFrame(ff_2019_09_23_VV)
ff_2019_09_23_VV['date'] = '23/09/2019'
ff_2019_09_23_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -8.946271     -10.151346      -7.807059  23/09/2019

# %%
df_VV = ff_2019_09_11_VV.append(ff_2019_09_23_VV)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019

# %% [markdown]
# #### 05/10/2019

# %%
# Zonal stats das formações florestais - VH
ff_2019_10_05_VH = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191005_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
ff_2019_10_05_VH = pd.DataFrame(ff_2019_10_05_VH)
ff_2019_10_05_VH['date'] = '05/10/2019'
ff_2019_10_05_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -14.761747     -15.883709     -13.709671  05/10/2019

# %%
df_VH = df_VH.append(ff_2019_10_05_VH)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019

# %%
# Zonal stats das formações florestais - VV
ff_2019_10_05_VV = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191005_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
ff_2019_10_05_VV = pd.DataFrame(ff_2019_10_05_VV)
ff_2019_10_05_VV['date'] = '05/10/2019'
ff_2019_10_05_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -8.965117     -10.161974      -7.846068  05/10/2019

# %%
df_VV = df_VV.append(ff_2019_10_05_VV)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019

# %% [markdown]
# #### 17/10/2019

# %%
# Zonal stats das formações florestais - VH
VH_2019_10_17 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191017_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2019_10_17 = pd.DataFrame(VH_2019_10_17)
VH_2019_10_17['date'] = '17/10/2019'
VH_2019_10_17
# Out:
#       median  percentile_25  percentile_75        date
# 0 -14.833183      -15.95212     -13.769723  17/10/2019

# %%
df_VH = df_VH.append(VH_2019_10_17)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019

# %%
# Zonal stats das formações florestais - VV
VV_2019_10_17 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191017_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2019_10_17 = pd.DataFrame(VV_2019_10_17)
VV_2019_10_17['date'] = '17/10/2019'
VV_2019_10_17
# Out:
#      median  percentile_25  percentile_75        date
# 0 -8.989421     -10.182878      -7.863969  17/10/2019

# %%
df_VV = df_VV.append(VV_2019_10_17)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019

# %% [markdown]
# #### 29/10/2019

# %%
# Zonal stats das formações florestais - VH
VH_2019_10_29 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191029_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2019_10_29 = pd.DataFrame(VH_2019_10_29)
VH_2019_10_29['date'] = '29/10/2019'
VH_2019_10_29
# Out:
#       median  percentile_25  percentile_75        date
# 0 -14.774204     -15.874969      -13.73286  29/10/2019

# %%
df_VH = df_VH.append(VH_2019_10_29)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019

# %%
# Zonal stats das formações florestais - VV
VV_2019_10_29 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191029_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2019_10_29 = pd.DataFrame(VV_2019_10_29)
VV_2019_10_29['date'] = '29/10/2019'
VV_2019_10_29
# Out:
#      median  percentile_25  percentile_75        date
# 0 -8.808178      -9.973522      -7.715626  29/10/2019

# %%
df_VV = df_VV.append(VV_2019_10_29)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019

# %% [markdown]
# #### 10/11/2019

# %%
# Zonal stats das formações florestais - VH
VH_2019_11_10 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191110_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2019_11_10 = pd.DataFrame(VH_2019_11_10)
VH_2019_11_10['date'] = '10/11/2019'
VH_2019_11_10
# Out:
#      median  percentile_25  percentile_75        date
# 0 -14.49867     -15.547886     -13.486499  10/11/2019

# %%
df_VH = df_VH.append(VH_2019_11_10)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019

# %%
# Zonal stats das formações florestais - VV
VV_2019_11_10 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191110_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2019_11_10 = pd.DataFrame(VV_2019_11_10)
VV_2019_11_10['date'] = '10/11/2019'
VV_2019_11_10
# Out:
#      median  percentile_25  percentile_75        date
# 0 -8.551652      -9.659606      -7.497291  10/11/2019

# %%
df_VV = df_VV.append(VV_2019_11_10)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019

# %% [markdown]
# #### 22/11/2019

# %%
# Zonal stats das formações florestais - VH
VH_2019_11_22 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191122_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2019_11_22 = pd.DataFrame(VH_2019_11_22)
VH_2019_11_22['date'] = '22/11/2019'
VH_2019_11_22
# Out:
#       median  percentile_25  percentile_75        date
# 0 -13.450316     -14.452454      -12.45935  22/11/2019

# %%
df_VH = df_VH.append(VH_2019_11_22)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019

# %%
# Zonal stats das formações florestais - VV
VV_2019_11_22 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191122_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2019_11_22 = pd.DataFrame(VV_2019_11_22)
VV_2019_11_22['date'] = '22/11/2019'
VV_2019_11_22
# Out:
#      median  percentile_25  percentile_75        date
# 0 -7.788669      -8.833969      -6.773244  22/11/2019

# %%
df_VV = df_VV.append(VV_2019_11_22)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019

# %% [markdown]
# #### 04/12/2019

# %%
# Zonal stats das formações florestais - VH
VH_2019_12_04 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191204_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2019_12_04 = pd.DataFrame(VH_2019_12_04)
VH_2019_12_04['date'] = '04/12/2019'
VH_2019_12_04
# Out:
#       median  percentile_25  percentile_75        date
# 0 -13.672564      -14.67348     -12.706918  04/12/2019

# %%
df_VH = df_VH.append(VH_2019_12_04)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019

# %%
# Zonal stats das formações florestais - VV
VV_2019_12_04 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191204_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2019_12_04 = pd.DataFrame(VV_2019_12_04)
VV_2019_12_04['date'] = '04/12/2019'
VV_2019_12_04
# Out:
#      median  percentile_25  percentile_75        date
# 0 -7.941161      -8.985092      -6.919617  04/12/2019

# %%
df_VV = df_VV.append(VV_2019_12_04)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019

# %% [markdown]
# #### 16/12/2019

# %%
# Zonal stats das formações florestais - VH
VH_2019_12_16 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191216_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2019_12_16 = pd.DataFrame(VH_2019_12_16)
VH_2019_12_16['date'] = '16/12/2019'
VH_2019_12_16
# Out:
#       median  percentile_25  percentile_75        date
# 0 -14.291553     -15.318024     -13.286716  16/12/2019

# %%
df_VH = df_VH.append(VH_2019_12_16)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019

# %%
# Zonal stats das formações florestais - VV
VV_2019_12_16 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191216_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2019_12_16 = pd.DataFrame(VV_2019_12_16)
VV_2019_12_16['date'] = '16/12/2019'
VV_2019_12_16
# Out:
#      median  percentile_25  percentile_75        date
# 0 -8.253855      -9.347502      -7.201205  16/12/2019

# %%
df_VV = df_VV.append(VV_2019_12_16)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019

# %% [markdown]
# #### 28/12/2019

# %%
# Zonal stats das formações florestais - VH
VH_2019_12_28 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191228_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2019_12_28 = pd.DataFrame(VH_2019_12_28)
VH_2019_12_28['date'] = '28/12/2019'
VH_2019_12_28
# Out:
#       median  percentile_25  percentile_75        date
# 0 -14.423731     -15.442473      -13.42221  28/12/2019

# %%
df_VH = df_VH.append(VH_2019_12_28)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019

# %%
# Zonal stats das formações florestais - VH
VV_2019_12_28 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20191228_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2019_12_28 = pd.DataFrame(VV_2019_12_28)
VV_2019_12_28['date'] = '28/12/2019'
VV_2019_12_28
# Out:
#      median  percentile_25  percentile_75        date
# 0 -8.487056      -9.564434      -7.420602  28/12/2019

# %%
df_VV = df_VV.append(VV_2019_12_28)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019

# %% [markdown]
# #### 09/01/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_01_09 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200109_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_01_09 = pd.DataFrame(VH_2020_01_09)
VH_2020_01_09['date'] = '09/01/2020'
VH_2020_01_09
# Out:
#       median  percentile_25  percentile_75        date
# 0 -14.167305     -15.163141     -13.167397  09/01/2020

# %%
df_VH = df_VH.append(VH_2020_01_09)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020

# %%
# Zonal stats das formações florestais - VH
VV_2020_01_09 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200109_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_01_09 = pd.DataFrame(VV_2020_01_09)
VV_2020_01_09['date'] = '09/01/2020'
VV_2020_01_09
# Out:
#      median  percentile_25  percentile_75        date
# 0 -8.167227      -9.248408      -7.101436  09/01/2020

# %%
df_VV = df_VV.append(VV_2020_01_09)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020

# %% [markdown]
# #### 21/01/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_01_21 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200121_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_01_21 = pd.DataFrame(VH_2020_01_21)
VH_2020_01_21['date'] = '21/01/2020'
VH_2020_01_21
# Out:
#       median  percentile_25  percentile_75        date
# 0 -13.726669     -14.746103     -12.735683  21/01/2020

# %%
df_VH = df_VH.append(VH_2020_01_21)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020
# 0 -13.726669     -14.746103     -12.735683  21/01/2020

# %%
# Zonal stats das formações florestais - VH
VV_2020_01_21 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200121_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_01_21 = pd.DataFrame(VV_2020_01_21)
VV_2020_01_21['date'] = '21/01/2020'
VV_2020_01_21
# Out:
#      median  percentile_25  percentile_75        date
# 0 -7.890148      -8.957268      -6.858192  21/01/2020

# %%
df_VV = df_VV.append(VV_2020_01_21)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020
# 0 -7.890148      -8.957268      -6.858192  21/01/2020

# %% [markdown]
# #### 02/02/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_02_02 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200202_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_02_02 = pd.DataFrame(VH_2020_02_02)
VH_2020_02_02['date'] = '02/02/2020'
VH_2020_02_02
# Out:
#       median  percentile_25  percentile_75        date
# 0 -14.538206     -15.564172     -13.540477  02/02/2020

# %%
df_VH = df_VH.append(VH_2020_02_02)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020
# 0 -13.726669     -14.746103     -12.735683  21/01/2020
# 0 -14.538206     -15.564172     -13.540477  02/02/2020

# %%
# Zonal stats das formações florestais - VH
VV_2020_02_02 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200202_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_02_02 = pd.DataFrame(VV_2020_02_02)
VV_2020_02_02['date'] = '02/02/2020'
VV_2020_02_02
# Out:
#      median  percentile_25  percentile_75        date
# 0 -8.379669      -9.468038      -7.306713  02/02/2020

# %%
df_VV = df_VV.append(VV_2020_02_02)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020
# 0 -7.890148      -8.957268      -6.858192  21/01/2020
# 0 -8.379669      -9.468038      -7.306713  02/02/2020

# %% [markdown]
# #### 14/02/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_02_14 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200214_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_02_14 = pd.DataFrame(VH_2020_02_14)
VH_2020_02_14['date'] = '14/02/2020'
VH_2020_02_14
# Out:
#       median  percentile_25  percentile_75        date
# 0 -13.609907     -14.604383     -12.645424  14/02/2020

# %%
df_VH = df_VH.append(VH_2020_02_14)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020
# 0 -13.726669     -14.746103     -12.735683  21/01/2020
# 0 -14.538206     -15.564172     -13.540477  02/02/2020
# 0 -13.609907     -14.604383     -12.645424  14/02/2020

# %%
# Zonal stats das formações florestais - VH
VV_2020_02_14 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200214_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_02_14 = pd.DataFrame(VV_2020_02_14)
VV_2020_02_14['date'] = '14/02/2020'
VV_2020_02_14
# Out:
#      median  percentile_25  percentile_75        date
# 0 -7.788153      -8.829734      -6.765245  14/02/2020

# %%
df_VV = df_VV.append(VV_2020_02_14)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020
# 0 -7.890148      -8.957268      -6.858192  21/01/2020
# 0 -8.379669      -9.468038      -7.306713  02/02/2020
# 0 -7.788153      -8.829734      -6.765245  14/02/2020

# %% [markdown]
# #### 26/02/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_02_26 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200226_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_02_26 = pd.DataFrame(VH_2020_02_26)
VH_2020_02_26['date'] = '26/02/2020'
VH_2020_02_26
# Out:
#       median  percentile_25  percentile_75        date
# 0 -13.751508     -14.755488      -12.77553  26/02/2020

# %%
df_VH = df_VH.append(VH_2020_02_26)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020
# 0 -13.726669     -14.746103     -12.735683  21/01/2020
# 0 -14.538206     -15.564172     -13.540477  02/02/2020
# 0 -13.609907     -14.604383     -12.645424  14/02/2020
# 0 -13.751508     -14.755488     -12.775530  26/02/2020

# %%
# Zonal stats das formações florestais - VH
VV_2020_02_26 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200226_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_02_26 = pd.DataFrame(VV_2020_02_26)
VV_2020_02_26['date'] = '26/02/2020'
VV_2020_02_26
# Out:
#      median  percentile_25  percentile_75        date
# 0 -7.794476      -8.854672      -6.761727  26/02/2020

# %%
df_VV = df_VV.append(VV_2020_02_26)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020
# 0 -7.890148      -8.957268      -6.858192  21/01/2020
# 0 -8.379669      -9.468038      -7.306713  02/02/2020
# 0 -7.788153      -8.829734      -6.765245  14/02/2020
# 0 -7.794476      -8.854672      -6.761727  26/02/2020

# %% [markdown]
# #### 09/03/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_03_09 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200309_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_03_09 = pd.DataFrame(VH_2020_03_09)
VH_2020_03_09['date'] = '09/03/2020'
VH_2020_03_09
# Out:
#     median  percentile_25  percentile_75        date
# 0 -13.5485     -14.530179     -12.595639  09/03/2020

# %%
df_VH = df_VH.append(VH_2020_03_09)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020
# 0 -13.726669     -14.746103     -12.735683  21/01/2020
# 0 -14.538206     -15.564172     -13.540477  02/02/2020
# 0 -13.609907     -14.604383     -12.645424  14/02/2020
# 0 -13.751508     -14.755488     -12.775530  26/02/2020
# 0 -13.548500     -14.530179     -12.595639  09/03/2020

# %%
# Zonal stats das formações florestais - VH
VV_2020_03_09 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200309_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_03_09 = pd.DataFrame(VV_2020_03_09)
VV_2020_03_09['date'] = '09/03/2020'
VV_2020_03_09
# Out:
#      median  percentile_25  percentile_75        date
# 0 -7.803637      -8.846292      -6.783248  09/03/2020

# %%
df_VV = df_VV.append(VV_2020_03_09)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020
# 0 -7.890148      -8.957268      -6.858192  21/01/2020
# 0 -8.379669      -9.468038      -7.306713  02/02/2020
# 0 -7.788153      -8.829734      -6.765245  14/02/2020
# 0 -7.794476      -8.854672      -6.761727  26/02/2020
# 0 -7.803637      -8.846292      -6.783248  09/03/2020

# %% [markdown]
# #### 21/03/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_03_21 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200321_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_03_21 = pd.DataFrame(VH_2020_03_21)
VH_2020_03_21['date'] = '21/03/2020'
VH_2020_03_21
# Out:
#       median  percentile_25  percentile_75        date
# 0 -13.728338     -14.716849     -12.756456  21/03/2020

# %%
df_VH = df_VH.append(VH_2020_03_21)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020
# 0 -13.726669     -14.746103     -12.735683  21/01/2020
# 0 -14.538206     -15.564172     -13.540477  02/02/2020
# 0 -13.609907     -14.604383     -12.645424  14/02/2020
# 0 -13.751508     -14.755488     -12.775530  26/02/2020
# 0 -13.548500     -14.530179     -12.595639  09/03/2020
# ...

# %%
# Zonal stats das formações florestais - VH
VV_2020_03_21 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200321_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_03_21 = pd.DataFrame(VV_2020_03_21)
VV_2020_03_21['date'] = '21/03/2020'
VV_2020_03_21
# Out:
#      median  percentile_25  percentile_75        date
# 0 -7.929066      -8.988666      -6.888104  21/03/2020

# %%
df_VV = df_VV.append(VV_2020_03_21)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020
# 0 -7.890148      -8.957268      -6.858192  21/01/2020
# 0 -8.379669      -9.468038      -7.306713  02/02/2020
# 0 -7.788153      -8.829734      -6.765245  14/02/2020
# 0 -7.794476      -8.854672      -6.761727  26/02/2020
# 0 -7.803637      -8.846292      -6.783248  09/03/2020
# ...

# %% [markdown]
# #### 02/04/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_04_02 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200402_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_04_02 = pd.DataFrame(VH_2020_04_02)
VH_2020_04_02['date'] = '02/04/2020'
VH_2020_04_02
# Out:
#       median  percentile_25  percentile_75        date
# 0 -14.124328     -15.115479      -13.15722  02/04/2020

# %%
df_VH = df_VH.append(VH_2020_04_02)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020
# 0 -13.726669     -14.746103     -12.735683  21/01/2020
# 0 -14.538206     -15.564172     -13.540477  02/02/2020
# 0 -13.609907     -14.604383     -12.645424  14/02/2020
# 0 -13.751508     -14.755488     -12.775530  26/02/2020
# 0 -13.548500     -14.530179     -12.595639  09/03/2020
# ...

# %%
# Zonal stats das formações florestais - VH
VV_2020_04_02 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200402_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_04_02 = pd.DataFrame(VV_2020_04_02)
VV_2020_04_02['date'] = '02/04/2020'
VV_2020_04_02
# Out:
#      median  percentile_25  percentile_75        date
# 0 -7.990138       -9.08628      -6.927521  02/04/2020

# %%
df_VV = df_VV.append(VV_2020_04_02)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020
# 0 -7.890148      -8.957268      -6.858192  21/01/2020
# 0 -8.379669      -9.468038      -7.306713  02/02/2020
# 0 -7.788153      -8.829734      -6.765245  14/02/2020
# 0 -7.794476      -8.854672      -6.761727  26/02/2020
# 0 -7.803637      -8.846292      -6.783248  09/03/2020
# ...

# %% [markdown]
# #### 14/04/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_04_14 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200414_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_04_14 = pd.DataFrame(VH_2020_04_14)
VH_2020_04_14['date'] = '14/04/2020'
VH_2020_04_14
# Out:
#       median  percentile_25  percentile_75        date
# 0 -13.615545     -14.604824     -12.645714  14/04/2020

# %%
df_VH = df_VH.append(VH_2020_04_14)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020
# 0 -13.726669     -14.746103     -12.735683  21/01/2020
# 0 -14.538206     -15.564172     -13.540477  02/02/2020
# 0 -13.609907     -14.604383     -12.645424  14/02/2020
# 0 -13.751508     -14.755488     -12.775530  26/02/2020
# 0 -13.548500     -14.530179     -12.595639  09/03/2020
# ...

# %%
# Zonal stats das formações florestais - VH
VV_2020_04_14 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200414_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_04_14 = pd.DataFrame(VV_2020_04_14)
VV_2020_04_14['date'] = '14/04/2020'
VV_2020_04_14
# Out:
#      median  percentile_25  percentile_75        date
# 0 -7.706583       -8.75066      -6.680281  14/04/2020

# %%
df_VV = df_VV.append(VV_2020_04_14)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020
# 0 -7.890148      -8.957268      -6.858192  21/01/2020
# 0 -8.379669      -9.468038      -7.306713  02/02/2020
# 0 -7.788153      -8.829734      -6.765245  14/02/2020
# 0 -7.794476      -8.854672      -6.761727  26/02/2020
# 0 -7.803637      -8.846292      -6.783248  09/03/2020
# ...

# %% [markdown]
# #### 26/04/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_04_26 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200426_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_04_26 = pd.DataFrame(VH_2020_04_26)
VH_2020_04_26['date'] = '26/04/2020'
VH_2020_04_26
# Out:
#       median  percentile_25  percentile_75        date
# 0 -13.984325     -14.958672     -13.011324  26/04/2020

# %%
df_VH = df_VH.append(VH_2020_04_26)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020
# 0 -13.726669     -14.746103     -12.735683  21/01/2020
# 0 -14.538206     -15.564172     -13.540477  02/02/2020
# 0 -13.609907     -14.604383     -12.645424  14/02/2020
# 0 -13.751508     -14.755488     -12.775530  26/02/2020
# 0 -13.548500     -14.530179     -12.595639  09/03/2020
# ...

# %%
# Zonal stats das formações florestais - VH
VV_2020_04_26 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200426_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_04_26 = pd.DataFrame(VV_2020_04_26)
VV_2020_04_26['date'] = '26/04/2020'
VV_2020_04_26
# Out:
#      median  percentile_25  percentile_75        date
# 0 -7.916779      -8.982137      -6.874116  26/04/2020

# %%
df_VV = df_VV.append(VV_2020_04_26)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020
# 0 -7.890148      -8.957268      -6.858192  21/01/2020
# 0 -8.379669      -9.468038      -7.306713  02/02/2020
# 0 -7.788153      -8.829734      -6.765245  14/02/2020
# 0 -7.794476      -8.854672      -6.761727  26/02/2020
# 0 -7.803637      -8.846292      -6.783248  09/03/2020
# ...

# %% [markdown]
# #### 08/05/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_05_08 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200508_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_05_08 = pd.DataFrame(VH_2020_05_08)
VH_2020_05_08['date'] = '08/05/2020'
VH_2020_05_08
# Out:
#       median  percentile_25  percentile_75        date
# 0 -14.197305     -15.216948     -13.207234  08/05/2020

# %%
df_VH = df_VH.append(VH_2020_05_08)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020
# 0 -13.726669     -14.746103     -12.735683  21/01/2020
# 0 -14.538206     -15.564172     -13.540477  02/02/2020
# 0 -13.609907     -14.604383     -12.645424  14/02/2020
# 0 -13.751508     -14.755488     -12.775530  26/02/2020
# 0 -13.548500     -14.530179     -12.595639  09/03/2020
# ...

# %%
# Zonal stats das formações florestais - VH
VV_2020_05_08 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200508_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_05_08 = pd.DataFrame(VV_2020_05_08)
VV_2020_05_08['date'] = '08/05/2020'
VV_2020_05_08
# Out:
#      median  percentile_25  percentile_75        date
# 0 -8.298611      -9.394722      -7.238148  08/05/2020

# %%
df_VV = df_VV.append(VV_2020_05_08)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020
# 0 -7.890148      -8.957268      -6.858192  21/01/2020
# 0 -8.379669      -9.468038      -7.306713  02/02/2020
# 0 -7.788153      -8.829734      -6.765245  14/02/2020
# 0 -7.794476      -8.854672      -6.761727  26/02/2020
# 0 -7.803637      -8.846292      -6.783248  09/03/2020
# ...

# %% [markdown]
# #### 20/05/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_05_20 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200520_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_05_20 = pd.DataFrame(VH_2020_05_20)
VH_2020_05_20['date'] = '20/05/2020'
VH_2020_05_20
# Out:
#      median  percentile_25  percentile_75        date
# 0 -14.25074     -15.263473     -13.262981  20/05/2020

# %%
df_VH = df_VH.append(VH_2020_05_20)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020
# 0 -13.726669     -14.746103     -12.735683  21/01/2020
# 0 -14.538206     -15.564172     -13.540477  02/02/2020
# 0 -13.609907     -14.604383     -12.645424  14/02/2020
# 0 -13.751508     -14.755488     -12.775530  26/02/2020
# 0 -13.548500     -14.530179     -12.595639  09/03/2020
# ...

# %%
# Zonal stats das formações florestais - VH
VV_2020_05_20 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200520_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_05_20 = pd.DataFrame(VV_2020_05_20)
VV_2020_05_20['date'] = '20/05/2020'
VV_2020_05_20
# Out:
#      median  percentile_25  percentile_75        date
# 0 -8.255959      -9.353335      -7.203884  20/05/2020

# %%
df_VV = df_VV.append(VV_2020_05_20)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020
# 0 -7.890148      -8.957268      -6.858192  21/01/2020
# 0 -8.379669      -9.468038      -7.306713  02/02/2020
# 0 -7.788153      -8.829734      -6.765245  14/02/2020
# 0 -7.794476      -8.854672      -6.761727  26/02/2020
# 0 -7.803637      -8.846292      -6.783248  09/03/2020
# ...

# %% [markdown]
# #### 01/06/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_06_01 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200601_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_06_01 = pd.DataFrame(VH_2020_06_01)
VH_2020_06_01['date'] = '01/06/2020'
VH_2020_06_01
# Out:
#      median  percentile_25  percentile_75        date
# 0 -14.75051     -15.778211     -13.737497  01/06/2020

# %%
df_VH = df_VH.append(VH_2020_06_01)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020
# 0 -13.726669     -14.746103     -12.735683  21/01/2020
# 0 -14.538206     -15.564172     -13.540477  02/02/2020
# 0 -13.609907     -14.604383     -12.645424  14/02/2020
# 0 -13.751508     -14.755488     -12.775530  26/02/2020
# 0 -13.548500     -14.530179     -12.595639  09/03/2020
# ...

# %%
# Zonal stats das formações florestais - VH
VV_2020_06_01 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200601_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_06_01 = pd.DataFrame(VV_2020_06_01)
VV_2020_06_01['date'] = '01/06/2020'
VV_2020_06_01
# Out:
#      median  percentile_25  percentile_75        date
# 0 -8.518916      -9.648068      -7.421063  01/06/2020

# %%
df_VV = df_VV.append(VV_2020_06_01)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020
# 0 -7.890148      -8.957268      -6.858192  21/01/2020
# 0 -8.379669      -9.468038      -7.306713  02/02/2020
# 0 -7.788153      -8.829734      -6.765245  14/02/2020
# 0 -7.794476      -8.854672      -6.761727  26/02/2020
# 0 -7.803637      -8.846292      -6.783248  09/03/2020
# ...

# %% [markdown]
# #### 13/06/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_06_13 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200613_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_06_13 = pd.DataFrame(VH_2020_06_13)
VH_2020_06_13['date'] = '13/06/2020'
VH_2020_06_13
# Out:
#    median  percentile_25  percentile_75        date
# 0 -14.678     -15.719754     -13.662988  13/06/2020

# %%
df_VH = df_VH.append(VH_2020_06_13)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020
# 0 -13.726669     -14.746103     -12.735683  21/01/2020
# 0 -14.538206     -15.564172     -13.540477  02/02/2020
# 0 -13.609907     -14.604383     -12.645424  14/02/2020
# 0 -13.751508     -14.755488     -12.775530  26/02/2020
# 0 -13.548500     -14.530179     -12.595639  09/03/2020
# ...

# %%
# Zonal stats das formações florestais - VH
VV_2020_06_13 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200613_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_06_13 = pd.DataFrame(VV_2020_06_13)
VV_2020_06_13['date'] = '13/06/2020'
VV_2020_06_13
# Out:
#      median  percentile_25  percentile_75        date
# 0 -8.614975      -9.758852      -7.517305  13/06/2020

# %%
df_VV = df_VV.append(VV_2020_06_13)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020
# 0 -7.890148      -8.957268      -6.858192  21/01/2020
# 0 -8.379669      -9.468038      -7.306713  02/02/2020
# 0 -7.788153      -8.829734      -6.765245  14/02/2020
# 0 -7.794476      -8.854672      -6.761727  26/02/2020
# 0 -7.803637      -8.846292      -6.783248  09/03/2020
# ...

# %% [markdown]
# #### 25/06/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_06_25 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200625_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_06_25 = pd.DataFrame(VH_2020_06_25)
VH_2020_06_25['date'] = '25/06/2020'
VH_2020_06_25
# Out:
#       median  percentile_25  percentile_75        date
# 0 -14.484138     -15.521685     -13.475473  25/06/2020

# %%
df_VH = df_VH.append(VH_2020_06_25)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020
# 0 -13.726669     -14.746103     -12.735683  21/01/2020
# 0 -14.538206     -15.564172     -13.540477  02/02/2020
# 0 -13.609907     -14.604383     -12.645424  14/02/2020
# 0 -13.751508     -14.755488     -12.775530  26/02/2020
# 0 -13.548500     -14.530179     -12.595639  09/03/2020
# ...

# %%
# Zonal stats das formações florestais - VH
VV_2020_06_25 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200625_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_06_25 = pd.DataFrame(VV_2020_06_25)
VV_2020_06_25['date'] = '25/06/2020'
VV_2020_06_25
# Out:
#      median  percentile_25  percentile_75        date
# 0 -8.316504      -9.458003      -7.220477  25/06/2020

# %%
df_VV = df_VV.append(VV_2020_06_25)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020
# 0 -7.890148      -8.957268      -6.858192  21/01/2020
# 0 -8.379669      -9.468038      -7.306713  02/02/2020
# 0 -7.788153      -8.829734      -6.765245  14/02/2020
# 0 -7.794476      -8.854672      -6.761727  26/02/2020
# 0 -7.803637      -8.846292      -6.783248  09/03/2020
# ...

# %% [markdown]
# #### 07/07/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_07_07 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200707_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_07_07 = pd.DataFrame(VH_2020_07_07)
VH_2020_07_07['date'] = '07/07/2020'
VH_2020_07_07
# Out:
#       median  percentile_25  percentile_75        date
# 0 -14.732661     -15.783398     -13.715786  07/07/2020

# %%
df_VH = df_VH.append(VH_2020_07_07)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020
# 0 -13.726669     -14.746103     -12.735683  21/01/2020
# 0 -14.538206     -15.564172     -13.540477  02/02/2020
# 0 -13.609907     -14.604383     -12.645424  14/02/2020
# 0 -13.751508     -14.755488     -12.775530  26/02/2020
# 0 -13.548500     -14.530179     -12.595639  09/03/2020
# ...

# %%
# Zonal stats das formações florestais - VH
VV_2020_07_07 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200707_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_07_07 = pd.DataFrame(VV_2020_07_07)
VV_2020_07_07['date'] = '07/07/2020'
VV_2020_07_07
# Out:
#      median  percentile_25  percentile_75        date
# 0 -8.664227      -9.799849      -7.583531  07/07/2020

# %%
df_VV = df_VV.append(VV_2020_07_07)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020
# 0 -7.890148      -8.957268      -6.858192  21/01/2020
# 0 -8.379669      -9.468038      -7.306713  02/02/2020
# 0 -7.788153      -8.829734      -6.765245  14/02/2020
# 0 -7.794476      -8.854672      -6.761727  26/02/2020
# 0 -7.803637      -8.846292      -6.783248  09/03/2020
# ...

# %% [markdown]
# #### 19/07/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_07_19 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200719_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_07_19 = pd.DataFrame(VH_2020_07_19)
VH_2020_07_19['date'] = '19/07/2020'
VH_2020_07_19
# Out:
#       median  percentile_25  percentile_75        date
# 0 -14.980335     -16.071268     -13.934534  19/07/2020

# %%
df_VH = df_VH.append(VH_2020_07_19)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020
# 0 -13.726669     -14.746103     -12.735683  21/01/2020
# 0 -14.538206     -15.564172     -13.540477  02/02/2020
# 0 -13.609907     -14.604383     -12.645424  14/02/2020
# 0 -13.751508     -14.755488     -12.775530  26/02/2020
# 0 -13.548500     -14.530179     -12.595639  09/03/2020
# ...

# %%
# Zonal stats das formações florestais - VH
VV_2020_07_19 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200719_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_07_19 = pd.DataFrame(VV_2020_07_19)
VV_2020_07_19['date'] = '19/07/2020'
VV_2020_07_19
# Out:
#      median  percentile_25  percentile_75        date
# 0 -8.896569     -10.035988      -7.809865  19/07/2020

# %%
df_VV = df_VV.append(VV_2020_07_19)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020
# 0 -7.890148      -8.957268      -6.858192  21/01/2020
# 0 -8.379669      -9.468038      -7.306713  02/02/2020
# 0 -7.788153      -8.829734      -6.765245  14/02/2020
# 0 -7.794476      -8.854672      -6.761727  26/02/2020
# 0 -7.803637      -8.846292      -6.783248  09/03/2020
# ...

# %% [markdown]
# #### 31/07/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_07_31 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200731_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_07_31 = pd.DataFrame(VH_2020_07_19)
VH_2020_07_31['date'] = '31/07/2020'
VH_2020_07_31
# Out:
#       median  percentile_25  percentile_75        date
# 0 -14.980335     -16.071268     -13.934534  31/07/2020

# %%
df_VH = df_VH.append(VH_2020_07_31)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020
# 0 -13.726669     -14.746103     -12.735683  21/01/2020
# 0 -14.538206     -15.564172     -13.540477  02/02/2020
# 0 -13.609907     -14.604383     -12.645424  14/02/2020
# 0 -13.751508     -14.755488     -12.775530  26/02/2020
# 0 -13.548500     -14.530179     -12.595639  09/03/2020
# ...

# %%
# Zonal stats das formações florestais - VH
VV_2020_07_31 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200731_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_07_31 = pd.DataFrame(VV_2020_07_31)
VV_2020_07_31['date'] = '31/07/2020'
VV_2020_07_31
# Out:
#      median  percentile_25  percentile_75        date
# 0 -8.914311     -10.067794      -7.815898  31/07/2020

# %%
df_VV = df_VV.append(VV_2020_07_31)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020
# 0 -7.890148      -8.957268      -6.858192  21/01/2020
# 0 -8.379669      -9.468038      -7.306713  02/02/2020
# 0 -7.788153      -8.829734      -6.765245  14/02/2020
# 0 -7.794476      -8.854672      -6.761727  26/02/2020
# 0 -7.803637      -8.846292      -6.783248  09/03/2020
# ...

# %% [markdown]
# #### 12/08/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_08_12 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200812_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_08_12 = pd.DataFrame(VH_2020_08_12)
VH_2020_08_12['date'] = '12/08/2020'
VH_2020_08_12
# Out:
#       median  percentile_25  percentile_75        date
# 0 -14.898872     -15.988243     -13.845633  12/08/2020

# %%
df_VH = df_VH.append(VH_2020_08_12)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020
# 0 -13.726669     -14.746103     -12.735683  21/01/2020
# 0 -14.538206     -15.564172     -13.540477  02/02/2020
# 0 -13.609907     -14.604383     -12.645424  14/02/2020
# 0 -13.751508     -14.755488     -12.775530  26/02/2020
# 0 -13.548500     -14.530179     -12.595639  09/03/2020
# ...

# %%
# Zonal stats das formações florestais - VH
VV_2020_08_12 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200812_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_08_12 = pd.DataFrame(VV_2020_08_12)
VV_2020_08_12['date'] = '12/08/2020'
VV_2020_08_12
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.005871     -10.142043      -7.923441  12/08/2020

# %%
df_VV = df_VV.append(VV_2020_08_12)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020
# 0 -7.890148      -8.957268      -6.858192  21/01/2020
# 0 -8.379669      -9.468038      -7.306713  02/02/2020
# 0 -7.788153      -8.829734      -6.765245  14/02/2020
# 0 -7.794476      -8.854672      -6.761727  26/02/2020
# 0 -7.803637      -8.846292      -6.783248  09/03/2020
# ...

# %% [markdown]
# #### 24/08/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_08_24 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200824_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_08_24 = pd.DataFrame(VH_2020_08_24)
VH_2020_08_24['date'] = '24/08/2020'
VH_2020_08_24
# Out:
#       median  percentile_25  percentile_75        date
# 0 -14.617777      -15.71711     -13.571981  24/08/2020

# %%
df_VH = df_VH.append(VH_2020_08_24)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020
# 0 -13.726669     -14.746103     -12.735683  21/01/2020
# 0 -14.538206     -15.564172     -13.540477  02/02/2020
# 0 -13.609907     -14.604383     -12.645424  14/02/2020
# 0 -13.751508     -14.755488     -12.775530  26/02/2020
# 0 -13.548500     -14.530179     -12.595639  09/03/2020
# ...

# %%
# Zonal stats das formações florestais - VH
VV_2020_08_24 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200824_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_08_24 = pd.DataFrame(VV_2020_08_24)
VV_2020_08_24['date'] = '24/08/2020'
VV_2020_08_24
# Out:
#      median  percentile_25  percentile_75        date
# 0 -8.824395      -9.984474      -7.738547  24/08/2020

# %%
df_VV = df_VV.append(VV_2020_08_24)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020
# 0 -7.890148      -8.957268      -6.858192  21/01/2020
# 0 -8.379669      -9.468038      -7.306713  02/02/2020
# 0 -7.788153      -8.829734      -6.765245  14/02/2020
# 0 -7.794476      -8.854672      -6.761727  26/02/2020
# 0 -7.803637      -8.846292      -6.783248  09/03/2020
# ...

# %% [markdown]
# #### 05/09/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_09_05 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200905_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_09_05 = pd.DataFrame(VH_2020_09_05)
VH_2020_09_05['date'] = '05/09/2020'
VH_2020_09_05
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.212109     -16.302706     -14.148263  05/09/2020

# %%
df_VH = df_VH.append(VH_2020_09_05)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020
# 0 -13.726669     -14.746103     -12.735683  21/01/2020
# 0 -14.538206     -15.564172     -13.540477  02/02/2020
# 0 -13.609907     -14.604383     -12.645424  14/02/2020
# 0 -13.751508     -14.755488     -12.775530  26/02/2020
# 0 -13.548500     -14.530179     -12.595639  09/03/2020
# ...

# %%
# Zonal stats das formações florestais - VH
VV_2020_09_05 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200905_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_09_05 = pd.DataFrame(VV_2020_09_05)
VV_2020_09_05['date'] = '05/09/2020'
VV_2020_09_05
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.217116     -10.389678      -8.113611  05/09/2020

# %%
df_VV = df_VV.append(VV_2020_09_05)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020
# 0 -7.890148      -8.957268      -6.858192  21/01/2020
# 0 -8.379669      -9.468038      -7.306713  02/02/2020
# 0 -7.788153      -8.829734      -6.765245  14/02/2020
# 0 -7.794476      -8.854672      -6.761727  26/02/2020
# 0 -7.803637      -8.846292      -6.783248  09/03/2020
# ...

# %% [markdown]
# #### 17/09/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_09_17 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200917_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_09_17 = pd.DataFrame(VH_2020_09_17)
VH_2020_09_17['date'] = '17/09/2020'
VH_2020_09_17
# Out:
#       median  percentile_25  percentile_75        date
# 0 -14.926628     -16.018373     -13.881052  17/09/2020

# %%
df_VH = df_VH.append(VH_2020_09_17)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020
# 0 -13.726669     -14.746103     -12.735683  21/01/2020
# 0 -14.538206     -15.564172     -13.540477  02/02/2020
# 0 -13.609907     -14.604383     -12.645424  14/02/2020
# 0 -13.751508     -14.755488     -12.775530  26/02/2020
# 0 -13.548500     -14.530179     -12.595639  09/03/2020
# ...

# %%
# Zonal stats das formações florestais - VH
VV_2020_09_17 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200917_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_09_17 = pd.DataFrame(VV_2020_09_17)
VV_2020_09_17['date'] = '17/09/2020'
VV_2020_09_17
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.117085     -10.282266      -7.995062  17/09/2020

# %%
df_VV = df_VV.append(VV_2020_09_17)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020
# 0 -7.890148      -8.957268      -6.858192  21/01/2020
# 0 -8.379669      -9.468038      -7.306713  02/02/2020
# 0 -7.788153      -8.829734      -6.765245  14/02/2020
# 0 -7.794476      -8.854672      -6.761727  26/02/2020
# 0 -7.803637      -8.846292      -6.783248  09/03/2020
# ...

# %% [markdown]
# #### 29/09/2020

# %%
# Zonal stats das formações florestais - VH
VH_2020_09_29 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200929_Orb_Cal_Spk_TC_dB.tif', band=1, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VH_2020_09_29 = pd.DataFrame(VH_2020_09_29)
VH_2020_09_29['date'] = '29/09/2020'
VH_2020_09_29
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.048832     -16.147053     -13.997788  29/09/2020

# %%
df_VH = df_VH.append(VH_2020_09_29)
df_VH
# Out:
#       median  percentile_25  percentile_75        date
# 0 -15.085649     -16.213120     -14.013806  11/09/2019
# 0 -14.724693     -15.873222     -13.640703  23/09/2019
# 0 -14.761747     -15.883709     -13.709671  05/10/2019
# 0 -14.833183     -15.952120     -13.769723  17/10/2019
# 0 -14.774204     -15.874969     -13.732860  29/10/2019
# 0 -14.498670     -15.547886     -13.486499  10/11/2019
# 0 -13.450316     -14.452454     -12.459350  22/11/2019
# 0 -13.672564     -14.673480     -12.706918  04/12/2019
# 0 -14.291553     -15.318024     -13.286716  16/12/2019
# 0 -14.423731     -15.442473     -13.422210  28/12/2019
# 0 -14.167305     -15.163141     -13.167397  09/01/2020
# 0 -13.726669     -14.746103     -12.735683  21/01/2020
# 0 -14.538206     -15.564172     -13.540477  02/02/2020
# 0 -13.609907     -14.604383     -12.645424  14/02/2020
# 0 -13.751508     -14.755488     -12.775530  26/02/2020
# 0 -13.548500     -14.530179     -12.595639  09/03/2020
# ...

# %%
# Zonal stats das formações florestais - VH
VV_2020_09_29 = zonal_stats(area, 'E:/SBSR_data/TIFF/S1A_IW_GRDH_1SDV_20200929_Orb_Cal_Spk_TC_dB.tif', band=2, 
                     stats=['median', 'percentile_25', 'percentile_75'], nodata=np.nan)
VV_2020_09_29 = pd.DataFrame(VV_2020_09_29)
VV_2020_09_29['date'] = '29/09/2020'
VV_2020_09_29
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.040489     -10.211084       -7.93034  29/09/2020

# %%
df_VV = df_VV.append(VV_2020_09_29)
df_VV
# Out:
#      median  percentile_25  percentile_75        date
# 0 -9.084757     -10.275243      -7.954180  11/09/2019
# 0 -8.946271     -10.151346      -7.807059  23/09/2019
# 0 -8.965117     -10.161974      -7.846068  05/10/2019
# 0 -8.989421     -10.182878      -7.863969  17/10/2019
# 0 -8.808178      -9.973522      -7.715626  29/10/2019
# 0 -8.551652      -9.659606      -7.497291  10/11/2019
# 0 -7.788669      -8.833969      -6.773244  22/11/2019
# 0 -7.941161      -8.985092      -6.919617  04/12/2019
# 0 -8.253855      -9.347502      -7.201205  16/12/2019
# 0 -8.487056      -9.564434      -7.420602  28/12/2019
# 0 -8.167227      -9.248408      -7.101436  09/01/2020
# 0 -7.890148      -8.957268      -6.858192  21/01/2020
# 0 -8.379669      -9.468038      -7.306713  02/02/2020
# 0 -7.788153      -8.829734      -6.765245  14/02/2020
# 0 -7.794476      -8.854672      -6.761727  26/02/2020
# 0 -7.803637      -8.846292      -6.783248  09/03/2020
# ...

# %%
df_VH = df_VH.reset_index(drop=True)
df_VH.to_csv('E:/SBSR_data/CSV/form_florestais_VH.csv', sep=',')

# %%
df_VV = df_VV.reset_index(drop=True)
df_VV.to_csv('E:/SBSR_data/CSV/form_florestais_VV.csv', sep=',')

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.plot(df_VH.date, df_VH['median'], 'g', marker='o', label='Mediana')
ax.plot(df_VH.date, df_VH['percentile_75'], 'or', label='Percentil - 75%')
ax.plot(df_VH.date, df_VH['percentile_25'], 'ob', label='Percentil - 25%')

plt.xticks(rotation=60)

plt.ylim(-16.5, -12.0)
plt.legend()
ax.set_xlabel('Data')
ax.set_ylabel('Mediana [dB]')

plt.savefig('C:/Users/jales/Desktop/SBSR_figures/FF/medianas_ff_vh.svg', dpi=None, facecolor='w', edgecolor='w',
        orientation='landscape', format='svg', transparent=False)

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.plot(df_VH.date, df_VH['median'], 'g', marker='o', label='Mediana - VH')
ax.plot(df_VV.date, df_VV['median'], 'orange', marker='o', label='Mediana - VV')
ax.plot(df_VH.date, df_VH['percentile_75'], 'or', label='Percentil - 75%')
ax.plot(df_VH.date, df_VH['percentile_25'], 'ob', label='Percentil - 25%')


ax.plot(df_VV.date, df_VV['percentile_75'], 'or')
ax.plot(df_VV.date, df_VV['percentile_25'], 'ob')

plt.xticks(rotation=45)
plt.title('Formação Florestal')

#plt.ylim(-18.0, -12.0)
plt.legend()
ax.set_xlabel('Data')
ax.set_ylabel('Mediana [dB]')

plt.savefig('C:/Users/jales/Desktop/SBSR_figures/FF/medianas_ff_vh_vv.svg', dpi=None, facecolor='w', edgecolor='w',
        orientation='landscape', format='svg', transparent=False)
